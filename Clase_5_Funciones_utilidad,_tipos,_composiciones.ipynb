# %%
Utilidad, tipos, compociciones

# %% [markdown]
# **Funciones: utilidad, tipos, composiciones**
#
# **Utilidad de las Funciones**
#
# Modelización y Descripción: Las funciones se utilizan para modelar y describir relaciones entre variables en diversos contextos científicos y aplicados.
#
# * Son herramientas para el análisis de datos
#
# *  En campos como la ingeniería y la economía, las funciones ayudan a optimizar recursos y diseñar sistemas eficientes.
#
# **Tipos de Funciones**
#
# Funciones Lineales:
# 𝑓
# (
# 𝑥
# )
# =
# 𝑎
# 𝑥
# +
# 𝑏
# f(x)=ax+b, donde
# 𝑎
# a y
# 𝑏
# b son constantes y la gráfica es una línea recta.
#
# Funciones Cuadráticas:
# 𝑓
# (
# 𝑥
# )
# =
# 𝑎
# 𝑥
# 2
# +
# 𝑏
# 𝑥
# +
# 𝑐
# f(x)=ax
# 2
#  +bx+c, donde la gráfica es una parábola.
#
# Funciones Exponenciales:
# 𝑓
# (
# 𝑥
# )
# =
# 𝑎
# ⋅
# 𝑏
# 𝑥
# f(x)=a⋅b
# x
#  , donde
# 𝑏
# b es la base y
# 𝑎
# a es una constante.
#
# Funciones Logarítmicas:
# 𝑓
# (
# 𝑥
# )
# =
# log
# ⁡
# 𝑏
# (
# 𝑥
# )
# f(x)=log
# b
# ​
#  (x), donde
# 𝑏
# b es la base del logaritmo.
#
# Funciones Trigonométricas:
# 𝑓
# (
# 𝑥
# )
# =
# sin
# ⁡
# (
# 𝑥
# )
# ,
# cos
# ⁡
# (
# 𝑥
# )
# ,
# tan
# ⁡
# (
# 𝑥
# )
# f(x)=sin(x),cos(x),tan(x), entre otras.
#
# **Composiciones de Funciones**
#
#
# La composición de funciones es una operación que combina dos funciones para producir una tercera función. Si tenemos dos funciones
# 𝑓
# :
# 𝐴
# →
# 𝐵
# f:A→B y
# 𝑔
# :
# 𝐵
# →
# 𝐶
# g:B→C, la composición de
# 𝑔
# g con
# 𝑓
# f se denota como
# 𝑔
# ∘
# 𝑓
# g∘f y se define como:
#
# (
# 𝑔
# ∘
# 𝑓
# )
# (
# 𝑥
# )
# =
# 𝑔
# (
# 𝑓
# (
# 𝑥
# )
# )![WhatsApp Image 2024-06-30 at 8.05.09 PM.jpeg](data:image/jpeg;base64,...)
# (g∘f)(x)=g(f(x))
#
# ![WhatsApp Image 2024-06-30 at 8.28.25 PM (1).jpeg](data:image/jpeg;base64,...)
#
# Las curvas de indiferencia son las convinaciones  y canastas de bienes, que le garantizan al individuo, el mismo nivel de utilidad.
#
# Tambien son el consepto de preimagen aplicado a la nocion de utilidad para describir el comportamiento de un individuo.
#
#    A->B
# f:
#  X->f(x)
#
# f(A)⊆B    f(A)={F(X) E B:X E A}
#
# Desimos que **f** es sobreyectiva
#
# si f(A)=B
#
# "=" Igualdad de elemento significa que el mismo elemento que esta en la izquierda esta ala derecha del igual.
#
# Cuando hablo de igualdad de numeros estoy diciendo que x y Y son numeros, lo que quiere decir qu estos son el mismo numero.
#
# x≤yʌx≥y
#
# Si hablamos de igualdad entre conjuntos Ya no es la misma nocion, los conjuntos no tienen en general una relacion de orden.
#
# E=f<->E⊆ F ʌF⊆E
#
# Como  f(A) ⊆ B Se cmple siempre, podemos decir
#
#
# f es sobreyectiva<->B⊆ F(A)
#
# Desimos que una funcion es sobreyectiva si solo si la imagen de la partida es igual al espacio de llegada.
#
#
# f subyectiva <-> ∀y e B, Ǝ X EA: F(X)=y
#
#
#   ∀xEA,  Ǝ/y E B: y = f(x)
#
#   f:IR->R
#
#      x->f(x)=x^2+1
#
# Nos dice que a cada elemento de x de los reales, le socia un elemento que es x^2 mas 1
#
#
# f(R)={1,+∞{
#
#   f:R+->{1,+∞{
#
#   F:X->F(X)=X^2+1
#
#   Tanto en sobreyectividad como en inyectividad o que cambio o estrinjo es el cambio de llegada, para convertir a una funcion para que sea bobreyectiva o inyectiva.
#
#   f es biyectiva <-> { f inyectiva
#                     { f sobreyectiva
#
#   por que nos importa la inyectividad, biyectividad
#
#   f tiene una funcion inversa -> que significa: significa que existe un funcion g que ba de B->A Y que a cada y le asocia  un g de (y):
#
#
#         B->A
#     Ǝg:
#         Y-> g(y):
#
#
# Sea E,F,G son conjuntos
#
# Sea f, g funciones.
#
# f:E->F  , g: f-> G
#
# f:x->f(x); g:y->c(y)
#
#
# La funcion compuesta de g o F es una funcion compues que va de E->G que en cada x-> (g0f)(x):= (f(x)
#
#
# vimos que una funcion es sobreyectiva  apartir de una definicion de conjuntos, es decir si el conjunto de B y el conjunto de F DE A o sea la imagen son iguales.
#
#
# Vimos la inyectividad  como una nocion intuitiva, una funciones inyectiva si para cada par  de elementos  distintos del espacio de partida tengo dos imagenes distintas de partidas  a su llegada
#
# Si tengo 2 dos elementos elementos en el espacio de partida que tiene  la misma imagen eso implica que son el mismo elemento.
